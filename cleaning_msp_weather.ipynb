# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import datetime
from datetime import datetime

# %% [markdown]
# Prepare data for analysis. Load files for decades, and then combine. Load 1880-1900 seperately because of date issue and then combine.

# %%
# use glob to find all files from folder
path = r'C:/Users/lizba/Desktop/projects/weather_lab/decades'
all_files = glob.glob(path + "/*.csv")
# use concat to combine all files
df = pd.concat((pd.read_csv(f) for f in all_files))
# check sample
df.sample(5)
# Out:
#             Date  Maximum Temperature degrees (F)  \
# 2116  10/17/2005                               66
# 1183   3/29/1963                               68
# 682   11/14/1971                               50
# 592    8/16/1931                               84
# 3409    5/3/1919                               50
#
#      Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 2116                              50                    0.2             0
# 1183                              37                   0.01             0
# 682                               42                      T             0
# 592                               62                      0             0
# 3409                              44                   0.39             0
#
#      Snow Depth (inches)
# 2116                   0
# 1183                   0
# 682                    0
# 592                    0
# 3409                   0

# %% [markdown]
# Write df to file to deal with index issue.

# %%
# write df to file
df.to_csv('data/data.csv', index=False)

# %%
import pandas as pd

# %%
#load 1870-2000
df1=pd.read_csv("1871-1880.csv")
df2=pd.read_csv("1880-1890.csv")
df3=pd.read_csv("1890-1900.csv")

# %%
df1.append(df2,df3, ignore_index=True)

#df.append(df2, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-db1ca63e1864> in <module>
# ----> 1 df1.append(df2,df3, ignore_index=True)
#       2
#       3 #df.append(df2, ignore_index=True)
#
# TypeError: append() got multiple values for argument 'ignore_index'

# %%
#append first two files
df= df1.append(df2)

# %%
#Append combined file with last file
df=df.append(df3)

# %%
df
# Out:
#             Date Maximum Temperature degrees (F)  \
# 0     1871-01-01                               M
# 1     1871-01-02                               M
# 2     1871-01-03                               M
# 3     1871-01-04                               M
# 4     1871-01-05                               M
# ...          ...                             ...
# 3647  1899-12-27                              17
# 3648  1899-12-28                               9
# 3649  1899-12-29                               6
# 3650  1899-12-30                               7
# 3651  1899-12-31                               8
#
#      Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 0                                  M                      0             M
# 1                                  M                      0             M
# 2                                  M                      0             M
# 3                                  M                      T             M
# ...

# %% [markdown]
# Preparing data files to merge, add datetime.

# %%
# write df to file
df.to_csv('data/data2.csv', index=False)

# %%
# add datetime to 1870-1900
df_1870_1900 = pd.read_csv('data2.csv')
df_1870_1900
# Out:
#              Date Maximum Temperature degrees (F)  \
# 0      1871-01-01                               M
# 1      1871-01-02                               M
# 2      1871-01-03                               M
# 3      1871-01-04                               M
# 4      1871-01-05                               M
# ...           ...                             ...
# 10587  1899-12-27                              17
# 10588  1899-12-28                               9
# 10589  1899-12-29                               6
# 10590  1899-12-30                               7
# 10591  1899-12-31                               8
#
#       Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 0                                   M                      0             M
# 1                                   M                      0             M
# 2                                   M                      0             M
# ...

# %%
# Add datetime
df_1870_1900['datetime'] = pd.to_datetime(df_1870_1900['Date'])
# extract date componants

df_1870_1900['day'] = df_1870_1900['datetime'].map(lambda x: x.day)
df_1870_1900['month'] = df_1870_1900['datetime'].map(lambda x: x.month)
df_1870_1900['year'] = df_1870_1900['datetime'].map(lambda x: x.year)
df_1870_1900
# Out:
#              Date Maximum Temperature degrees (F)  \
# 0      1871-01-01                               M
# 1      1871-01-02                               M
# 2      1871-01-03                               M
# 3      1871-01-04                               M
# 4      1871-01-05                               M
# ...           ...                             ...
# 10587  1899-12-27                              17
# 10588  1899-12-28                               9
# 10589  1899-12-29                               6
# 10590  1899-12-30                               7
# 10591  1899-12-31                               8
#
#       Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 0                                   M                      0             M
# 1                                   M                      0             M
# 2                                   M                      0             M
# ...

# %%
df_to_present
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-e8d1dda18a45> in <module>
# ----> 1 df_to_present
#
# NameError: name 'df_to_present' is not defined

# %%
#load df from 1900 to present from csv
df_to_present = pd.read_csv('data/data.csv')
df_to_present.sample()
# Out:
#            Date  Maximum Temperature degrees (F)  \
# 8511  4/22/1923                               49
#
#      Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 8511                              41                      0             0
#
#      Snow Depth (inches)
# 8511                   0

# %%
# add date time
df_to_present['datetime'] = pd.to_datetime(df_to_present['Date'])
# extract date componants
df_to_present['day'] = df_to_present['datetime'].map(lambda x: x.day)
df_to_present['month'] = df_to_present['datetime'].map(lambda x: x.month)
df_to_present['year'] = df_to_present['datetime'].map(lambda x: x.year)
df_to_present.sample()
# Out:
#             Date  Maximum Temperature degrees (F)  \
# 10121  9/18/1927                               60
#
#       Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 10121                              48                      0             0
#
#       Snow Depth (inches)   datetime  day  month  year
# 10121                   0 1927-09-18   18      9  1927

# %%
# combine df's of different dates
full_df= df_1870_1900.append(df_to_present)

# %%
# check df
full_df.sample()
# Out:
#            Date Maximum Temperature degrees (F)  \
# 558  1872-07-12                               M
#
#     Minimum Temperature degrees (F) Precipitation (inches) Snow (inches)  \
# 558                               M                      0             M
#
#     Snow Depth (inches)   datetime  day  month  year
# 558                   M 1872-07-12   12      7  1872

# %%
# change column names
full_df.columns=[['Date','MaxTemp','MinTemp','Precip','Snow','SnowDepth','datetime','day','month','year']]

# %%
# check df
full_df.to_csv('full_df.csv')

# %%
import pandas as pd

# %%
full_df=pd.read_csv('data/full_df.csv')

# %%
# creat seasons

winter = full_df[(full_df['month'] == 12) | (full_df['month']==1) | (full_df['month']==2)]

# %%
# insert season name
winter['season'] = 'Winter'
# Out:
# <ipython-input-9-c80820db9f94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   winter['season'] = 'Winter'

# %%
winter.sample()
# Out:
#        Unnamed: 0       Date MaxTemp MinTemp Precip Snow SnowDepth  \
# 49325       38733  1/18/2006      26      14      T    T         1
#
#          datetime  day  month  year  season
# 49325  2006-01-18   18      1  2006  Winter

# %%
# make new df's based on seasons
spring = full_df[(full_df['month'] == 3) | (full_df['month']==4) | (full_df['month']==5)]
summer = full_df[(full_df['month'] == 6) | (full_df['month']==7) | (full_df['month']==8)]
fall = full_df[(full_df['month'] == 9) | (full_df['month']==10) | (full_df['month']==11)]

# %%
spring['season'] = 'Spring'
summer['season'] = 'Summer'
fall['season'] =  'Fall'
# Out:
# <ipython-input-13-14658c02a934>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   spring['season'] = 'Spring'
# <ipython-input-13-14658c02a934>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summer['season'] = 'Summer'
# <ipython-input-13-14658c02a934>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# append spring to winter
combo_1 = winter.append(spring)

# %%
# append suumer
combo_3 = combo_1.append(summer)

# %%
# append fall
full = combo_3.append(fall)

# %%
# full dateaset
full
# Out:
#        Unnamed: 0        Date MaxTemp MinTemp Precip Snow SnowDepth  \
# 0               0  1871-01-01       M       M      0    M         M
# 1               1  1871-01-02       M       M      0    M         M
# 2               2  1871-01-03       M       M      0    M         M
# 3               3  1871-01-04       M       M      T    M         M
# 4               4  1871-01-05       M       M      0    M         M
# ...           ...         ...     ...     ...    ...  ...       ...
# 54751       44159  11/26/2020      36      28      0    0         0
# 54752       44160  11/27/2020      37      27      0    0         0
# 54753       44161  11/28/2020      50      32      0    0         0
# 54754       44162  11/29/2020      40      22      0    0         0
# 54755       44163  11/30/2020      29      17      0    0         0
#
#          datetime  day  month  year  season
# 0      1871-01-01    1      1  1871  Winter
# 1      1871-01-02    2      1  1871  Winter
# ...

# %%
full.to_csv('data/msp_historical_weather.csv',index=False)
